# %%
import pandas as pd

file_path = 'Resources/Telehealth-Services-Provided-to-the-MedicaidCHIP-Population.csv'
df = pd.read_csv(file_path)
df.head(15)
# Out:
#       State  Year   Month             TelehealthType ServiceType ServiceCount  \
# 0   Alabama  2018  201801           Live audio/video         All       6,905
# 1   Alabama  2018  201801           Other telehealth         All         -
# 2   Alabama  2018  201801  Remote patient monitoring         All         -
# 3   Alabama  2018  201801          Store and forward         All         -
# 4   Alabama  2018  201802           Live audio/video         All       4,821
# 5   Alabama  2018  201802           Other telehealth         All         -
# 6   Alabama  2018  201802  Remote patient monitoring         All         -
# 7   Alabama  2018  201802          Store and forward         All         -
# 8   Alabama  2018  201803           Live audio/video         All       2,269
# 9   Alabama  2018  201803           Other telehealth         All         -
# 10  Alabama  2018  201803  Remote patient monitoring         All          DS
# ...

# %%
# Drop the 'DataQuality' column; too many null values
df = df.drop(columns=['DataQuality'])
